# %%
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
NoTreatment = pd.read_csv("NoTreatmentSortedFormatted.csv", header=None)
Buffer = pd.read_csv("BufferSortedFormatted.csv", header=None)
S1 = pd.read_csv("S1SortedFormatted.csv", header=None)

dfNT = pd.DataFrame(NoTreatment)
dfNT = dfNT.dropna(how = "all")

dfB = pd.DataFrame(Buffer)
dfB = dfB.dropna(how = "all")

dfS1 = pd.DataFrame(S1)
dfS1 = dfS1.dropna(how = "all")

dfS1
# Out:
#           0      1      2      3
# 0    Length  23.19    NaN    NaN
# 1    Length  18.03    NaN    NaN
# 2    Length  20.02    NaN    NaN
# 3    Length  20.40    NaN    NaN
# 4    Length  25.18    NaN    NaN
# 5    Length  14.14    NaN    NaN
# 6    Length  22.02    NaN    NaN
# 7    Length  15.03    NaN    NaN
# 8    Length  18.00    NaN    NaN
# 9    Length  15.03    NaN    NaN
# 10   Length  23.02    NaN    NaN
# 11   Length  33.14    NaN    NaN
# 12   Length  18.00    NaN    NaN
# 13   Length  27.17    NaN    NaN
# 14   Length  32.14    NaN    NaN
# 15   Length  15.00    NaN    NaN
# 16   Length  25.00    NaN    NaN
# 17   Length  29.61    NaN    NaN
# 18   Length  15.13    NaN    NaN
# 19   Length  17.26    NaN    NaN
# 20   Length  23.54    NaN    NaN
# 21   Length  31.00    NaN    NaN
# 22   Length  29.00    NaN    NaN
# 23   Length  17.00    NaN    NaN
# 24   Length  20.40    NaN    NaN
# 25   Length  19.00    NaN    NaN
# 26   Length  25.50    NaN    NaN
# ...

# %%
bCounts = dfB.groupby([0]).count()
ntCounts = dfNT.groupby([0]).count()
s1Counts = dfS1.groupby([0]).count()

bCounts.drop(columns=[2,3,4])
ntCounts.drop(columns=[2,3,4])
s1Counts.drop(columns=[2,3])
# Out:
#           1
# 0
# G/R/T     5
# Length  181
# Line    273

# %%
bGRGT = dfB[dfB[0] == "G/R/G/T"]
bGRT = dfB[dfB[0] == "G/R/T"]
bR = dfB[dfB[0] == "Line"]
bG = dfB[dfB[0] == "Length"]

ntGRGT = dfNT[dfNT[0] == "G/R/G/T"]
ntGRT = dfNT[dfNT[0] == "G/R/T"]
ntR = dfNT[dfNT[0] == "Line"]
ntG = dfNT[dfNT[0] == "Length"]
ntRGRT = dfNT[dfNT[0] == "R/G/R/T"]

s1R = dfS1[dfS1[0] == "Line"]
s1G = dfS1[dfS1[0] == "Length"]
s1GRT = dfS1[dfS1[0] == "G/R/T"]

# %%
bGRT
# Out:
#          0      1      2       3   4
# 766  G/R/T  29.00  54.00   83.00 NaN
# 768  G/R/T  60.00  31.00   91.00 NaN
# 770  G/R/T  21.00  40.00   61.00 NaN
# 772  G/R/T  21.92  17.96   39.88 NaN
# 777  G/R/T  66.00  70.00  136.00 NaN
# 779  G/R/T  40.27  28.96   69.23 NaN
# 781  G/R/T  67.00  35.00  102.00 NaN
# 783  G/R/T  43.00  35.00   78.00 NaN
# 785  G/R/T  39.01  41.89   80.90 NaN
# 787  G/R/T  37.00  33.00   70.00 NaN
# 789  G/R/T  30.00  98.00  128.00 NaN
# 791  G/R/T  15.00  29.00   44.00 NaN
# 793  G/R/T  25.34  26.16   51.50 NaN
# 795  G/R/T  21.00  40.00   61.00 NaN
# 797  G/R/T  21.00  43.00   64.00 NaN
# 799  G/R/T  29.42  28.71   58.13 NaN
# 801  G/R/T  30.00  17.00   47.00 NaN
# 803  G/R/T  31.48  48.46   79.94 NaN
# 805  G/R/T  17.00  43.00   60.00 NaN
# 807  G/R/T  18.00  67.00   85.00 NaN
# 809  G/R/T  23.00  71.00   94.00 NaN
# 811  G/R/T  38.00  38.00   76.00 NaN
# 813  G/R/T  18.00  70.00   88.00 NaN

# %%
labels = 'G/R/G', 'G/R', 'R', 'G', 'R/G/R'
sizes = ntCounts[1]

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Percentage of each segment type with no treatment')


labels2 = 'G/R/G', 'G/R', 'R', 'G'
sizes2 = bCounts[1]

fig1, ax2 = plt.subplots()
ax2.pie(sizes2, labels=labels2, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax2.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Percentage of each segment type with buffer')


labels3 = 'G/R', 'R', 'G'
sizes3 = s1Counts[1]

fig1, ax3 = plt.subplots()
ax3.pie(sizes3, labels=labels3, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax3.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Percentage of each segment type with s1')
plt.show()

# %%
fig1, ax1 = plt.subplots(figsize=(10,10))


x,y = ecdf(bR[1]) #R only
plt.scatter(x=x, y=y, label = "R")

x,y = ecdf(bG[1]) #G only
plt.scatter(x=x, y=y, label = "G")

x,y = ecdf(bGRT[3]) #G+R
plt.scatter(x=x, y=y, label = "G/R")

x,y = ecdf(bGRGT[4]) #R in middle
plt.scatter(x=x, y=y, label = "G/R/G")

#x,y = ecdf(terminallengths) #G in middle
#plt.scatter(x=x, y=y, label = "R/G/R")

ax1.legend()
plt.xlabel('Length', fontsize=16)
plt.ylabel('Cumulative probability', fontsize=16)
plt.title('Length distributions for each segment type with buffer')

fig1, ax2 = plt.subplots(figsize=(10,10))


x,y = ecdf(ntR[1]) #R only
plt.scatter(x=x, y=y, label = "R")

x,y = ecdf(ntG[1]) #G only
plt.scatter(x=x, y=y, label = "G")

x,y = ecdf(ntGRT[3]) #G + R
plt.scatter(x=x, y=y, label = "G/R")

x,y = ecdf(ntGRGT[4]) #R in middle
plt.scatter(x=x, y=y, label = "G/R/G")

x,y = ecdf(ntRGRT[4]) #G in middle
plt.scatter(x=x, y=y, label = "R/G/R")

ax2.legend()
plt.xlabel('Length', fontsize=16)
plt.ylabel('Cumulative probability', fontsize=16)
plt.title('Length distributions for each segment type no treatment')

fig1, ax3 = plt.subplots(figsize=(10,10))


x,y = ecdf(s1R[1]) #R only
plt.scatter(x=x, y=y, label = "R")

x,y = ecdf(s1G[1]) #G only
plt.scatter(x=x, y=y, label = "G")

x,y = ecdf(s1GRT[3]) #G + R
plt.scatter(x=x, y=y, label = "G/R")

ax3.legend()
plt.xlabel('Length', fontsize=16)
plt.ylabel('Cumulative probability', fontsize=16)
plt.title('Length distributions for each segment type S1')

plt.show()

# %%
fig1, ax1 = plt.subplots(figsize=(10,10))


x,y = ecdf(bR[1]) #R only
plt.plot(x, y, label = "R")

x,y = ecdf(bG[1]) #G only
plt.plot(x, y, label = "G")

x,y = ecdf(bGRT[3]) #G+R
plt.plot(x, y, label = "G/R")

x,y = ecdf(bGRGT[4]) #R in middle
plt.plot(x, y, label = "G/R/G")

#x,y = ecdf(terminallengths) #G in middle
#plt.plot(x, y, label = "R/G/R")

ax1.legend()
plt.xlabel('Length', fontsize=16)
plt.ylabel('Cumulative probability', fontsize=16)
plt.title('Length distributions for each segment type with buffer')

fig1, ax2 = plt.subplots(figsize=(10,10))


x,y = ecdf(ntR[1]) #R only
plt.plot(x, y, label = "R")

x,y = ecdf(ntG[1]) #G only
plt.plot(x, y, label = "G")

x,y = ecdf(ntGRT[3]) #G + R
plt.plot(x, y, label = "G/R")

x,y = ecdf(ntGRGT[4]) #R in middle
plt.plot(x, y, label = "G/R/G")

x,y = ecdf(ntRGRT[4]) #G in middle
plt.plot(x, y, label = "R/G/R")

ax2.legend()
plt.xlabel('Length', fontsize=16)
plt.ylabel('Cumulative probability', fontsize=16)
plt.title('Length distributions for each segment type no treatment')


plt.show()

# %%
allRb = bR[1]
allRb.append(bGRT[2])
allRb.append(bGRGT[4])

allGb = bG[1]
allGb.append(bGRT[1])
allGb.append(bGRGT[1])
allGb.append(bGRGT[3])

GRGgb = bGRGT[1]
GRGgb.append(bGRGT[3])

allRnt = ntR[1]
allRnt.append(ntGRT[2])
allRnt.append(ntGRGT[4])
allRnt.append(ntRGRT[1])
allRnt.append(ntRGRT[3])

allGnt = ntG[1]
allGnt.append(ntGRT[1])
allGnt.append(ntGRGT[1])
allGnt.append(ntGRGT[3])
allGnt.append(ntRGRT[2])

RGRrnt = ntRGRT[1]
RGRrnt.append(ntRGRT[3])

GRGgnt = ntGRGT[1]
GRGgnt.append(ntGRGT[3])
# Out:
# 789    89.0
# 793    88.0
# 789    35.0
# 793    50.0
# dtype: float64

# %%
fig1, ax1 = plt.subplots(figsize=(10,10))


x,y = ecdf(bR[1]) #R only
plt.scatter(x=x, y=y, label = "R")

#x,y = ecdf(allRb) #all R
#plt.scatter(x=x, y=y, label = "All R")

x,y = ecdf(bGRT[2]) #G + R only R
plt.scatter(x=x, y=y, label = "Ongoing fork R")

x,y = ecdf(bGRGT[2]) #R in middle
plt.scatter(x=x, y=y, label = "G/R/G R")

ax1.legend()
plt.xlabel('Length', fontsize=16)
plt.ylabel('Cumulative probability', fontsize=16)
plt.title('Length distributions for each R segment type buffer')


plt.show()

# %%
fig1, ax1 = plt.subplots(figsize=(10,10))


x,y = ecdf(ntR[1]) #R only
plt.scatter(x=x, y=y, label = "R")

#x,y = ecdf(allRnt) #all R
#plt.scatter(x=x, y=y, label = "All R")

x,y = ecdf(ntGRT[2]) #G + R only R
plt.scatter(x=x, y=y, label = "Ongoing fork R")

x,y = ecdf(ntGRGT[2]) #R in middle
plt.scatter(x=x, y=y, label = "G/R/G R")

x,y = ecdf(RGRrnt) #R in sides
plt.scatter(x=x, y=y, label = "R/G/R R")

ax1.legend()
plt.xlabel('Length', fontsize=16)
plt.ylabel('Cumulative probability', fontsize=16)
plt.title('Length distributions for each R segment type no treatment')


plt.show()

# %%
fig1, ax1 = plt.subplots(figsize=(10,10))


x,y = ecdf(bG[1]) #G only
plt.scatter(x=x, y=y, label = "G")

#x,y = ecdf(allRb) #all R
#plt.scatter(x=x, y=y, label = "All R")

x,y = ecdf(bGRT[1]) #G + R only R
plt.scatter(x=x, y=y, label = "Ongoing fork G")

x,y = ecdf(GRGgb) #R in side
plt.scatter(x=x, y=y, label = "G/R/G G")

ax1.legend()
plt.xlabel('Length', fontsize=16)
plt.ylabel('Cumulative probability', fontsize=16)
plt.title('Length distributions for each G segment type buffer')


plt.show()

# %%
fig1, ax1 = plt.subplots(figsize=(10,10))


x,y = ecdf(ntG[1]) #G only
plt.scatter(x=x, y=y, label = "G")

#x,y = ecdf(allRb) #all R
#plt.scatter(x=x, y=y, label = "All R")

x,y = ecdf(ntGRT[1]) #G + R only R
plt.scatter(x=x, y=y, label = "Ongoing fork G")

x,y = ecdf(GRGgnt) #G in side
plt.scatter(x=x, y=y, label = "G/R/G G")

x,y = ecdf(ntRGRT[2]) #G in center
plt.scatter(x=x, y=y, label = "R/G/R G")

ax1.legend()
plt.xlabel('Length', fontsize=16)
plt.ylabel('Cumulative probability', fontsize=16)
plt.title('Length distributions for each G segment type no treatment')


plt.show()

# %%
fig1, ax1 = plt.subplots(figsize=(10,10))


x,y = ecdf(ntG[1]) #G no treatment
plt.scatter(x=x, y=y, label = "no treatment")

x,y = ecdf(bG[1]) #G buffer
plt.scatter(x=x, y=y, label = "buffer")

x,y = ecdf(s1G[1]) #G s1
plt.scatter(x=x, y=y, label = "S1")

ax1.legend()
plt.xlabel('Length', fontsize=16)
plt.ylabel('Cumulative probability', fontsize=16)
plt.title('Length distributions for each G segments by treatment')


plt.show()

# %%
fig1, ax1 = plt.subplots(figsize=(10,10))


x,y = ecdf(ntR[1]) #R no treatment
plt.scatter(x=x, y=y, label = "no treatment")

x,y = ecdf(bR[1]) #R buffer
plt.scatter(x=x, y=y, label = "buffer")

x,y = ecdf(s1R[1]) #R s1
plt.scatter(x=x, y=y, label = "S1")

ax1.legend()
plt.xlabel('Length', fontsize=16)
plt.ylabel('Cumulative probability', fontsize=16)
plt.title('Length distributions for each R segments by treatment')


plt.show()

# %%
fig1, ax1 = plt.subplots(figsize=(10,10))


x,y = ecdf(ntR[1]) #R no treatment
plt.scatter(x=x, y=y, label = "R no treatment")

x,y = ecdf(bR[1]) #R buffer
plt.scatter(x=x, y=y, label = "R buffer")

x,y = ecdf(s1R[1]) #R s1
plt.scatter(x=x, y=y, label = "R S1")

x,y = ecdf(ntG[1]) #G no treatment
plt.scatter(x=x, y=y, label = "G no treatment")

x,y = ecdf(bG[1]) #G buffer
plt.scatter(x=x, y=y, label = "G buffer")

x,y = ecdf(s1G[1]) #G s1
plt.scatter(x=x, y=y, label = "G S1")

ax1.legend()
plt.xlabel('Length', fontsize=16)
plt.ylabel('Cumulative probability', fontsize=16)
plt.title('Length distributions for each segment by treatment')


plt.show()

# %%
#Empirical cumulative distribution function
def ecdf(data):
    x = np.sort(data)
    n = x.size
    y = np.arange(1, n+1) / n
    return(x,y)
